# %%
# %sql

CREATE DATABASE IF NOT EXISTS live
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

USE live
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
INBOUND_PATH = "/mnt/yahoo-finances-bg/inbound/"

FILE_TEST_PATH = "/FileStore/tables/finances_AAPL_21*.csv"

RAW_PATH = "/mnt/yahoo-finances-bg/raw/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("/mnt/yahoo-finances-bg/inbound")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: [FileInfo(path=&#39;dbfs:/mnt/yahoo-finances-bg/inbound/2022/&#39;, name=&#39;2022/&#39;, size=0)]</div>

# %%
get_sch_data = spark.read.format('csv').option('header', 'true').load(FILE_TEST_PATH)
data_static_sch = get_sch_data.schema

get_sch_data.createOrReplaceTempView("vw_data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_bronze = spark.readStream \
 .schema(data_static_sch) \
 .format("csv") \
 .option("header", "true") \
 .option("maxFilesPerTrigger", "1") \
 .load(INBOUND_PATH + "*/*/*/*.csv")

df_bronze.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: True</div>

# %%
df_bronze \
 .writeStream \
 .format("parquet") \
 .outputMode("append") \
 .partitionBy("year", "month", "ticker") \
 .option("checkpointLocation", RAW_PATH + "_checkpoint/") \
 .start(RAW_PATH)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f002deee7d0&gt;</div>

# %%
# %sql 

SELECT * FROM parquet.`/mnt/yahoo-finances-bg/raw`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>open</th><th>close</th><th>high</th><th>volume</th><th>low</th><th>timestamp</th><th>day</th><th>year</th><th>month</th><th>ticker</th></tr></thead><tbody><tr><td>16.125</td><td>6417722</td><td>16.3799991607666</td><td>16.229999542236328</td><td>16.3700008392334</td><td>1642689000</td><td>21</td><td>2022</td><td>1</td><td>VALE</td></tr><tr><td>16.21500015258789</td><td>3358880</td><td>16.309999465942383</td><td>16.250699996948242</td><td>16.229999542236328</td><td>1642692600</td><td>21</td><td>2022</td><td>1</td><td>VALE</td></tr><tr><td>16.235000610351562</td><td>3779589</td><td>16.3700008392334</td><td>16.3700008392334</td><td>16.2549991607666</td><td>1642696200</td><td>21</td><td>2022</td><td>1</td><td>VALE</td></tr><tr><td>16.300100326538086</td><td>2881656</td><td>16.399999618530273</td><td>16.334999084472656</td><td>16.364999771118164</td><td>1642699800</td><td>21</td><td>2022</td><td>1</td><td>VALE</td></tr><tr><td>16.280000686645508</td><td>4782015</td><td>16.3799991607666</td><td>16.283599853515625</td><td>16.334999084472656</td><td>1642703400</td><td>21</td><td>2022</td><td>1</td><td>VALE</td></tr><tr><td>16.020000457763672</td><td>6965979</td><td>16.28499984741211</td><td>16.02669906616211</td><td>16.28